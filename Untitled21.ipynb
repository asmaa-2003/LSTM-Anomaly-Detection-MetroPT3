# %% [markdown]
# <a href="https://colab.research.google.com/github/asmaa-2003/LSTM-Anomaly--detection/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, f1_score
import warnings
warnings.filterwarnings("ignore")

# %%
PATH = "MetroPT3.csv"

df = pd.read_csv(PATH, parse_dates=["timestamp"])
df = df.sort_values("timestamp").reset_index(drop=True)

print(df.shape)
df.head()
# Out:
# (7381, 17)
#    Unnamed: 0           timestamp    TP2    TP3     H1  DV_pressure  \
# 0           0 2020-02-01 00:00:00 -0.012  9.358  9.340       -0.024
# 1          10 2020-02-01 00:00:10 -0.014  9.348  9.332       -0.022
# 2          20 2020-02-01 00:00:19 -0.012  9.338  9.322       -0.022
# 3          30 2020-02-01 00:00:29 -0.012  9.328  9.312       -0.022
# 4          40 2020-02-01 00:00:39 -0.012  9.318  9.302       -0.022
#
#    Reservoirs  Oil_temperature  Motor_current  COMP  DV_eletric  Towers  MPG  \
# 0       9.358           53.600         0.0400   1.0         0.0     1.0  1.0
# 1       9.348           53.675         0.0400   1.0         0.0     1.0  1.0
# 2       9.338           53.600         0.0425   1.0         0.0     1.0  1.0
# 3       9.328           53.425         0.0400   1.0         0.0     1.0  1.0
# 4       9.318           53.475         0.0400   1.0         0.0     1.0  1.0
#
#    LPS  Pressure_switch  Oil_level  Caudal_impulses
# ...

# %%
horizon = 180  # ≈ 30 دقيقة (حسب sampling ~10s)

fault_now = (
    (df["TP3"] < 8.5) |
    (df["Oil_temperature"] > 70) |
    (df["Motor_current"] > 0.5)
).astype(int)

df["fault_future"] = fault_now.shift(-horizon)

df = df.dropna()
df["fault_future"] = df["fault_future"].astype(int)

print("Fault rate:", df["fault_future"].mean())
# Out:
# Fault rate: 0.5389529232051105

# %%
sensor_cols = [
    "TP2","TP3","H1","DV_pressure","Reservoirs",
    "Oil_temperature","Motor_current"
]

for col in sensor_cols:
    df[f"{col}_mean"] = df[col].rolling(20).mean()
    df[f"{col}_std"]  = df[col].rolling(20).std()
    df[f"{col}_diff"] = df[col].diff()

df = df.fillna(0)

# %%
drop_cols = ["timestamp", "fault_future"]

X = df.drop(columns=drop_cols)
y = df["fault_future"]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
def create_sequences(X, y, seq_len=60):
    Xs, ys = [], []

    for i in range(len(X) - seq_len):
        Xs.append(X[i:i+seq_len])
        ys.append(y.iloc[i+seq_len])

    return np.array(Xs), np.array(ys)

X_seq, y_seq = create_sequences(X_scaled, y, seq_len=60)

print(X_seq.shape)
# Out:
# (7141, 60, 37)

# %%
split = int(len(X_seq)*0.8)

X_train = X_seq[:split]
X_test  = X_seq[split:]

y_train = y_seq[:split]
y_test  = y_seq[split:]

print(X_train.shape, X_test.shape)
# Out:
# (5712, 60, 37) (1429, 60, 37)

# %%
model = models.Sequential()

model.add(layers.LSTM(64, return_sequences=True,
                      input_shape=(X_seq.shape[1], X_seq.shape[2])))
model.add(layers.Dropout(0.2))

model.add(layers.LSTM(32))
model.add(layers.Dropout(0.2))

model.add(layers.Dense(1, activation="sigmoid"))

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 64)         │        26,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# ...

# %%
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=64,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - accuracy: 0.7613 - loss: 0.5042 - val_accuracy: 0.5559 - val_loss: 1.0046
# Epoch 2/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - accuracy: 0.8253 - loss: 0.4054 - val_accuracy: 0.5594 - val_loss: 1.1271
# Epoch 3/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.8446 - loss: 0.3533 - val_accuracy: 0.5367 - val_loss: 1.2171
# Epoch 4/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.8636 - loss: 0.3196 - val_accuracy: 0.5017 - val_loss: 1.4192
# Epoch 5/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.8949 - loss: 0.2534 - val_accuracy: 0.5087 - val_loss: 1.6558
# Epoch 6/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.9181 - loss: 0.2006 - val_accuracy: 0.4860 - val_loss: 1.7143
# Epoch 7/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.9123 - loss: 0.2116 - val_accuracy: 0.5192 - val_loss: 1.7798
# Epoch 8/10
# ...

# %%
proba = model.predict(X_test).flatten()

best_f1 = 0
best_t = 0.5

for t in np.linspace(0.1, 0.5, 10):
    pred = (proba > t).astype(int)
    f1 = f1_score(y_test, pred)

    if f1 > best_f1:
        best_f1 = f1
        best_t = t

print("Best threshold:", best_t)

y_pred = (proba > best_t).astype(int)

print(classification_report(y_test, y_pred))
print("F1:", f1_score(y_test, y_pred))
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Best threshold: 0.1
#               precision    recall  f1-score   support
#
#            0       0.50      0.35      0.42       570
#            1       0.64      0.77      0.70       859
#
#     accuracy                           0.60      1429
#    macro avg       0.57      0.56      0.56      1429
# weighted avg       0.59      0.60      0.59      1429
#
# F1: 0.6988335100742312
